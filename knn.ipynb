# %% [markdown]
# <a href="https://colab.research.google.com/github/NassimF/knn-implementation-breast-cancer/blob/main/knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split



 
# Loading data
dataset = load_breast_cancer(return_X_y=True,as_frame= True)
#print(type(dataset))

# Create feature and target arrays
X = dataset[0]
y = dataset[1]

 

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# plot learning curves
import numpy as np
import matplotlib.pyplot as plt



num_neighbors = list(range(1,10))
train_accuracy = np.empty(len(num_neighbors))
test_accuracy = np.empty(len(num_neighbors))
 
# Loop over K values
for i, k in enumerate(num_neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
     
    # Compute training and test accuracy
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)
 
# Generate plot
plt.plot(num_neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(num_neighbors, train_accuracy, label = 'Training dataset Accuracy')
 
plt.legend()
plt.xlabel('n_num_neighbors')
plt.ylabel('Accuracy')
plt.show()
